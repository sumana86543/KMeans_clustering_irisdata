# %% [markdown]
# # Unsupervised Learning
# ### Predict Optimum Number of Clusters

# %% [markdown]
# ## Task 2
# ##### From the given ‘Iris’ dataset, predict the optimum number of clusters and represent it visually.
# ##### Dataset : https://drive.google.com/file/d/11Iq7YvbWZbt8VXjfm06brx66b10YiwK-/view?usp=sharing
# ##### Sample Solution : https://drive.google.com/file/d/1Yjz8dzSbpAPwJdcVb20eFWniIDbs6ZH7/view?usp=sharing

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import pandas as pd
import warnings
import seaborn as sns
warnings.filterwarnings('ignore')

# Load the iris dataset
iris = pd.read_csv('Iris.csv')
iris_df=iris.drop(['Id'],axis=1)
iris_df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
setosa=iris_df[iris_df['Species']=='Iris-setosa']
virginica=iris_df[iris_df['Species']=='Iris-virginica']
versicolor=iris_df[iris_df['Species']=='Iris-versicolor']

# %%
# Finding the optimum number of clusters for k-means classification

x = iris_df.iloc[:, [0, 1, 2, 3]].values

from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
    
# Plotting the results onto a line graph, 
# `allowing us to observe 'The elbow'
plt.plot(figsize=(10,10))
plt.plot(range(1, 11), wcss,marker='o',markersize=13,markerfacecolor='r',ls='-')
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans
data=iris_df.drop(['Species'],axis=1)
#data = iris_df.iloc[:, [0, 1, 2, 3]].values

X, _ = make_blobs(n_samples=150, centers=3, n_features=4)

df = pd.DataFrame(X, columns=['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])

kmeans = KMeans(n_clusters=2)

y = kmeans.fit_predict(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

df['Cluster'] = y
df['id']=iris_df['Species']
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Cluster  \
# 0      -2.583523     -2.420894      -9.576929      0.662816        1
# 1      -1.934059     -3.041573      -8.875406     -0.239318        1
# 2      -4.569663     -0.969823      -5.261403     -8.068341        0
# 3      -6.203224     -2.626126      -4.448096     -8.528099        0
# 4      -4.916788     -2.220216      -5.601956     -5.766430        0
#
#             id
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa

# %%
d=df.groupby(['id','Cluster']).count()
d
# Out:
#                          SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# id              Cluster
# Iris-setosa     0                   36            36             36
#                 1                   14            14             14
# Iris-versicolor 0                   30            30             30
#                 1                   20            20             20
# Iris-virginica  0                   34            34             34
#                 1                   16            16             16
#
#                          PetalWidthCm
# id              Cluster
# Iris-setosa     0                  36
#                 1                  14
# Iris-versicolor 0                  30
#                 1                  20
# Iris-virginica  0                  34
#                 1                  16

# %%
import seaborn as sns
sns.heatmap(iris_df.corr())

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data=setosa,hue='Species',palette='Set1')

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data=virginica,hue='Species',palette='Set2')

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',data=versicolor,hue='Species',palette='Oranges')

# %%
kmeans = KMeans(n_clusters = 3, init = 'k-means++',
                max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %%
plt.figure(figsize = (12,8))
plt.scatter(x[y_kmeans == 0, 0], x[y_kmeans == 0, 1], 
            s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 1, 0], x[y_kmeans == 1, 1], 
            s = 100, c = 'teal', label = 'Iris-versicolour')
plt.scatter(x[y_kmeans == 2, 0], x[y_kmeans == 2, 1],
            s = 100, c = 'orange', label = 'Iris-virginica')

plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], 
            s = 100, c = 'blue', label = 'Centroids')

plt.legend(frameon=False)
